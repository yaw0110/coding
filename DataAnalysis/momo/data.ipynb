# %%
import pandas as pd
import numpy as np

# %%
# 将数据转换成字典形式
data = {
    '地区': ['广州', '广州', '广州', '广州', '广州'],
    '年份': [2020, 2019, 2018, 2017, 2016],
    '审计局人数（人）': [178, 192, 155, 143, 175],
    '完成审计项目（个）': [94, 48, 86, 144, 312],
    '审计查出主要问题金额（万元）': [2358883, 942303, 1757520, 7512705, 8297174],
    '审计期间整改金额（万元）': [270639, 145807, 351012, 99500, 71365],
    '审计处理处罚金额（万元）': [158104, 268809, 41607, 536392, 253166],
    '移送处理事项（件）': [40, 27, 16, 86, 29],
    '移送处理涉及金额（亿元）': [1.99, 3.4, 2.47, 357.48, 7.43],
    '审计促进更改落实有关问题资金（万元）': [434694, 304229, 205985, 211080, 224712],
    '审计提出建议（条）': [296, 286, 184, 278, 369],
    '审计采纳建议（条）': [562, 0, 134, 122, 214],
    '提交审计信息（篇次）': [243, 221, 34, 31, 149],
    '被批示、采用审计信息（篇次）': [117, 0, 13, 4, 25],
    '提交审计报告数量（篇）': [109, 103, 141, 271, 443],
    '审计机关决算支出（万元）': [15750.52, 12686.65, 11186.36, 10579.21, 9270.16],
    '一般公共预算收入（亿元）': [1722.8, 1699, 1634.2, 1536.7, 1393.6],
    '一般公共预算支出（亿元）': [2042.66, 1712.97, 2100.33, 1522.01, 1520.11],
    '审计支出比率': [0.0771, 0.0741, 0.0533, 0.0695, 0.061],
    '年末人口数（万人）': [1874, 1831.2, 1798.1, 1746.3, 1678.4],
    '人均审计支出': [8.404759872, 6.928052643, 6.221211279, 6.058071351, 5.523212583],
    '审计效率指标_人均完成审计项目数': [0.528089888, 0.25, 0.55483871, 1.006993007, 1.782857143],
    '审计质量指标_整改率': [0.114731846, 0.15473473, 0.19972006, 0.013244231, 0.008601121],
    '审计质量指标_处罚率': [0.067024944, 0.285268114, 0.023673699, 0.071397985, 0.030512317],
    '审计效果指标_建议采纳率': [1.898648649, 0, 0.72826087, 0.438848921, 0.579945799],
    '审计效果指标_信息采用率': [0.481481481, 0, 0.382352941, 0.129032258, 0.167785235],
    '审计重视程度_人均审计支出': [8.404759872, 6.928052643, 6.221211279, 6.058071351, 5.523212583]
}

# 创建DataFrame
df_guangzhou = pd.DataFrame(data)

# 显示DataFrame
df_guangzhou
# Out:
#    地区    年份  审计局人数（人）  完成审计项目（个）  审计查出主要问题金额（万元）  审计期间整改金额（万元）  审计处理处罚金额（万元）  \
# 0  广州  2020       178         94         2358883        270639        158104
# 1  广州  2019       192         48          942303        145807        268809
# 2  广州  2018       155         86         1757520        351012         41607
# 3  广州  2017       143        144         7512705         99500        536392
# 4  广州  2016       175        312         8297174         71365        253166
#
#    移送处理事项（件）  移送处理涉及金额（亿元）  审计促进更改落实有关问题资金（万元）  ...  一般公共预算支出（亿元）  审计支出比率  \
# 0         40          1.99              434694  ...       2042.66  0.0771
# 1         27          3.40              304229  ...       1712.97  0.0741
# 2         16          2.47              205985  ...       2100.33  0.0533
# 3         86        357.48              211080  ...       1522.01  0.0695
# 4         29          7.43              224712  ...       1520.11  0.0610
#
# ...

# %%
# 创建数据字典
data = {
    '地区': ['深圳', '深圳', '深圳', '深圳', '深圳'],
    '年份': [2020, 2019, 2018, 2017, 2016],
    '审计局人数（人）': [135, 148, 175, 174, 175],
    '完成审计项目（个）': [66, 47, 71, 400, 560],
    '审计查出主要问题金额（万元）': [661057, 1818282, 7857757, 7073645, 2764068],
    '审计期间整改金额（万元）': [53796, 622387, 272373, 451709, 274103],
    '审计处理处罚金额（万元）': [47956, 165147, 1033211, 387205, 173254],
    '移送处理事项（件）': [105, 37, 24, 28, 52],
    '移送处理涉及金额（亿元）': [3.52, 8.46, 9.13, 29.83, 5.09],
    '审计采纳建议（条）': [135, 109, 112, 435, 142],
    '提交审计信息（篇次）': [71, 35, 26, 25, 153],
    '被批示、采用审计信息（篇次）': [43, 21, 15, 18, 92],
    '提交审计报告数量（篇）': [96, 69, 86, 539, 4241],
    '审计机关决算支出（万元）': [11596.39, 14459.21, 14759.13, 13773.18, 9747.69],
    '一般公共预算收入（亿元）': [3857.4, 3773.4, 3538.4, 3332.1, 3136.5],
    '一般公共预算支出（亿元）': [3135.75, 3501.6, 3147, 3244.24, 3212.38],
    '审计支出比率': [0.0370, 0.0413, 0.0469, 0.0425, 0.0303],
    '年末人口数（万人）': [1763.4, 1710.4, 1666.1, 1587.3, 1495.4],
    '人均审计支出': [6.576154021, 8.453700889, 8.858489887, 8.677112077, 6.518449913],
    '审计效率指标_人均完成审计项目数': [0.488888889, 0.317567568, 0.405714286, 2.298850575, 3.2],
    '审计质量指标_整改率': [0.081378762, 0.34229399, 0.034662945, 0.063858025, 0.099166518],
    '审计质量指标_处罚率': [0.072544425, 0.090825845, 0.131489304, 0.054739106, 0.062680802],
    '审计效果指标_信息采用率': [0.605633803, 0.6, 0.576923077, 0.72, 0.60130719],
    '审计重视程度_人均审计支出': [6.576154021, 8.453700889, 8.858489887, 8.677112077, 6.518449913]
}

# 创建数据框
df_shenzhen = pd.DataFrame(data)

# 显示数据框
df_shenzhen
# Out:
#    地区    年份  审计局人数（人）  完成审计项目（个）  审计查出主要问题金额（万元）  审计期间整改金额（万元）  审计处理处罚金额（万元）  \
# 0  深圳  2020       135         66          661057         53796         47956
# 1  深圳  2019       148         47         1818282        622387        165147
# 2  深圳  2018       175         71         7857757        272373       1033211
# 3  深圳  2017       174        400         7073645        451709        387205
# 4  深圳  2016       175        560         2764068        274103        173254
#
#    移送处理事项（件）  移送处理涉及金额（亿元）  审计采纳建议（条）  ...  一般公共预算收入（亿元）  一般公共预算支出（亿元）  \
# 0        105          3.52        135  ...        3857.4       3135.75
# 1         37          8.46        109  ...        3773.4       3501.60
# 2         24          9.13        112  ...        3538.4       3147.00
# 3         28         29.83        435  ...        3332.1       3244.24
# 4         52          5.09        142  ...        3136.5       3212.38
#
#    审计支出比率  年末人口数（万人）    人均审计支出  审计效率指标_人均完成审计项目数  审计质量指标_整改率  审计质量指标_处罚率  \
# ...

# %%
# 创建数据字典
data_zhuhai = {
    '地区': ['珠海', '珠海', '珠海', '珠海', '珠海'],
    '年份': [2020, 2019, 2018, 2017, 2016],
    '审计局人数（人）': [71, 66, 59, 53, 52],
    '完成审计项目（个）': [42, 35, 56, 68, 117],
    '审计查出主要问题金额（万元）': [666961, 318644, 497887, 1047807, 1496660],
    '审计期间整改金额（万元）': [14598, 99366, 50185, 194720, 272013],
    '审计处理处罚金额（万元）': [49850, 41823, 18128, 39686, 67128],
    '移送处理事项（件）': [14, 4, 29, 10, 25],
    '移送处理涉及金额（亿元）': [3.33, 0.0997, 2.96, 7.35, 11.63],
    '审计促进更改落实有关问题资金（万元）': [173334, 43324, 39896, 123500, 223501],
    '审计采纳建议（条）': [173, 115, 87, 89, 101],
    '提交审计信息（篇次）': [68, 58, 104, 47, 50],
    '被批示、采用审计信息（篇次）': [16, 11, 22, 8, 9],
    '提交审计报告数量（篇）': [80, 34, 86, 243, 172],
    '审计机关决算支出（万元）': [6048.72, 4440.01, 3186.11, 3240.03, 2954.61],
    '一般公共预算收入（亿元）': [379.1, 344.5, 331.5, 314.4, 292.4],
    '一般公共预算支出（亿元）': [677.6, 615.7, 572.5, 493.9, 417.2],
    '审计支出比率': [0.0893, 0.0721, 0.0557, 0.0656, 0.0708],
    '年末人口数（万人）': [245, 233.2, 220.9, 207, 196],
    '人均审计支出': [24.68865306, 19.039494, 14.42331372, 15.65231884, 15.07454082],
    '审计效率指标_人均完成审计项目数': [0.591549296, 0.53030303, 0.949152542, 1.283018868, 2.25],
    '审计质量指标_整改率': [0.021887337, 0.311840173, 0.100795964, 0.18583575, 0.181746689],
    '审计质量指标_处罚率': [0.074742001, 0.13125306, 0.036409868, 0.037875296, 0.04485187],
    '审计效果指标_信息采用率': [0.235294118, 0.189655172, 0.211538462, 0.170212766, 0.18],
    '审计重视程度_人均审计支出': [24.68865306, 19.039494, 14.42331372, 15.65231884, 15.07454082]
}

# 创建数据框
df_zhuhai = pd.DataFrame(data_zhuhai)

# 显示数据框
df_zhuhai
# Out:
#    地区    年份  审计局人数（人）  完成审计项目（个）  审计查出主要问题金额（万元）  审计期间整改金额（万元）  审计处理处罚金额（万元）  \
# 0  珠海  2020        71         42          666961         14598         49850
# 1  珠海  2019        66         35          318644         99366         41823
# 2  珠海  2018        59         56          497887         50185         18128
# 3  珠海  2017        53         68         1047807        194720         39686
# 4  珠海  2016        52        117         1496660        272013         67128
#
#    移送处理事项（件）  移送处理涉及金额（亿元）  审计促进更改落实有关问题资金（万元）  ...  一般公共预算收入（亿元）  \
# 0         14        3.3300              173334  ...         379.1
# 1          4        0.0997               43324  ...         344.5
# 2         29        2.9600               39896  ...         331.5
# 3         10        7.3500              123500  ...         314.4
# 4         25       11.6300              223501  ...         292.4
#
#    一般公共预算支出（亿元）  审计支出比率  年末人口数（万人）     人均审计支出  审计效率指标_人均完成审计项目数  审计质量指标_整改率  \
# ...

# %%
# 创建数据字典
data_foshan = {
    '地区': ['佛山', '佛山', '佛山', '佛山', '佛山'],
    '年份': [2020, 2019, 2018, 2017, 2016],
    '审计局人数（人）': [59, 56, 57, 60, 44],
    '完成审计项目（个）': [27, 29, 18, 37, 111],
    '审计查出主要问题金额（万元）': [816832, 478180, 915686, 1173956, 37200],
    '审计期间整改金额（万元）': [12895, 2670, 24370, 83651, 4721],
    '审计处理处罚金额（万元）': [87804, 12552, 81281, 2140, 17523],
    '移送处理事项（件）': [15, 8, 19, 37, 35],
    '移送处理涉及金额（亿元）': [5.32, 3.41, 6.26, 8.71, 7.58],
    '审计促进更改落实有关问题资金（万元）': [42737, 274185, 81591, 13581, 31300],
    '审计提出建议（条）': [126, 130, 74, 90, 204],
    '提交审计信息（篇次）': [67, 45, 27, 71, 165],
    '被批示、采用审计信息（篇次）': [23, 9, 5, 24, 37],
    '提交审计报告数量（篇）': [104, 42, 33, 58, 142],
    '审计机关决算支出（万元）': [3513.42, 3412.34, 2842.35, 2028.24, 2209.87],
    '一般公共预算收入（亿元）': [753.6, 731.6, 703.1, 661.6, 604.5],
    '一般公共预算支出（亿元）': [1003, 941.3, 806.5, 775, 695.9],
    '审计支出比率': [0.0350, 0.0363, 0.0352, 0.0262, 0.0318],
    '年末人口数（万人）': [951.88, 815.86, 790.59, 765.67, 746.27],
    '人均审计支出': [3.691032483, 4.182506803, 3.59522635, 2.648974101, 2.96122047],
    '审计效率指标_人均完成审计项目数': [0.457627119, 0.517857143, 0.315789474, 0.616666667, 2.522727273],
    '审计质量指标_整改率': [0.0157866, 0.005583671, 0.026613927, 0.071255652, 0.126908602],
    '审计质量指标_处罚率': [0.10749334, 0.026249529, 0.088765144, 0.001822896, 0.471048387],
    '审计效果指标_信息采用率': [0.343283582, 0.2, 0.185185185, 0.338028169, 0.224242424],
    '审计重视程度_人均审计支出': [3.691032483, 4.182506803, 3.59522635, 2.648974101, 2.96122047]
}

# 创建数据框
df_foshan = pd.DataFrame(data_foshan)

# 显示数据框
df_foshan
# Out:
#    地区    年份  审计局人数（人）  完成审计项目（个）  审计查出主要问题金额（万元）  审计期间整改金额（万元）  审计处理处罚金额（万元）  \
# 0  佛山  2020        59         27          816832         12895         87804
# 1  佛山  2019        56         29          478180          2670         12552
# 2  佛山  2018        57         18          915686         24370         81281
# 3  佛山  2017        60         37         1173956         83651          2140
# 4  佛山  2016        44        111           37200          4721         17523
#
#    移送处理事项（件）  移送处理涉及金额（亿元）  审计促进更改落实有关问题资金（万元）  ...  一般公共预算收入（亿元）  \
# 0         15          5.32               42737  ...         753.6
# 1          8          3.41              274185  ...         731.6
# 2         19          6.26               81591  ...         703.1
# 3         37          8.71               13581  ...         661.6
# 4         35          7.58               31300  ...         604.5
#
#    一般公共预算支出（亿元）  审计支出比率  年末人口数（万人）    人均审计支出  审计效率指标_人均完成审计项目数  审计质量指标_整改率  \
# ...

# %%
# 创建数据字典
data_jiangmen = {
    '地区': ['江门', '江门', '江门', '江门', '江门'],
    '年份': [2020, 2019, 2018, 2017, 2016],
    '审计局人数（人）': [71, 74, 57, 52, 42],
    '完成审计项目（个）': [43, 31, 39, 53, 284],
    '审计查出主要问题金额（万元）': [628466, 383980, 470810, 748248, 704],
    '审计期间整改金额（万元）': [15396, 77784, 3943, 58431, 233],
    '审计处理处罚金额（万元）': [13188, 6151, 699, 3629, 98],
    '移送处理事项（件）': [18, 27, 16, 2, 6],
    '移送处理涉及金额（亿元）': [1.06, 2.96, 1.14, 0.011, 0.0219],
    '审计促进更改落实有关问题资金（万元）': [15725, 187054, 19998, 20207.13, 14407.46],
    '审计提出建议（条）': [167, 445, 558, 181, 358],
    '审计采纳建议（条）': [142, 424, 518, 143, 301],
    '提交审计信息（篇次）': [90, 1, 32, 53, 71],
    '被批示、采用审计信息（篇次）': [22, 1, 9, 27, 24],
    '提交审计报告数量（篇）': [69, 46, 57, 92, 555],
    '审计机关决算支出（万元）': [2233.75, 1902.2, 2051.29, 1503.22, 1330.7],
    '一般公共预算收入（亿元）': [264, 256.8, 244, 222.4, 204.2],
    '一般公共预算支出（亿元）': [442.4, 421.2, 377.9, 333.3, 293.2],
    '审计支出比率': [0.0505, 0.0452, 0.0543, 0.0451, 0.0454],
    '年末人口数（万人）': [480.4, 475.3, 470.4, 465.1, 461.8],
    '人均审计支出': [4.649771024, 4.002103934, 4.360735544, 3.232036121, 2.881550455],
    '审计效率指标_人均完成审计项目数': [0.605633803, 0.418918919, 0.684210526, 1.019230769, 6.761904762],
    '审计质量指标_整改率': [0.024497745, 0.202573051, 0.008374928, 0.078090419, 0.330965909],
    '审计质量指标_处罚率': [0.020984429, 0.016019063, 0.001484675, 0.004849996, 0.139204545],
    '审计效果指标_建议采纳率': [0.850299401, 0.952808989, 0.928315412, 0.790055249, 0.840782123],
    '审计效果指标_信息采用率': [0.244444444, 1, 0.28125, 0.509433962, 0.338028169],
    '审计重视程度_人均审计支出': [4.649771024, 4.002103934, 4.360735544, 3.232036121, 2.881550455]
}

# 创建数据框
df_jiangmen = pd.DataFrame(data_jiangmen)

# 显示数据框
(df_jiangmen)
# Out:
#    地区    年份  审计局人数（人）  完成审计项目（个）  审计查出主要问题金额（万元）  审计期间整改金额（万元）  审计处理处罚金额（万元）  \
# 0  江门  2020        71         43          628466         15396         13188
# 1  江门  2019        74         31          383980         77784          6151
# 2  江门  2018        57         39          470810          3943           699
# 3  江门  2017        52         53          748248         58431          3629
# 4  江门  2016        42        284             704           233            98
#
#    移送处理事项（件）  移送处理涉及金额（亿元）  审计促进更改落实有关问题资金（万元）  ...  一般公共预算支出（亿元）  审计支出比率  \
# 0         18        1.0600            15725.00  ...         442.4  0.0505
# 1         27        2.9600           187054.00  ...         421.2  0.0452
# 2         16        1.1400            19998.00  ...         377.9  0.0543
# 3          2        0.0110            20207.13  ...         333.3  0.0451
# 4          6        0.0219            14407.46  ...         293.2  0.0454
#
# ...

# %%
data = {
    '地区': ['肇庆', '肇庆', '肇庆', '肇庆', '肇庆'],
    '年份': [2020, 2019, 2018, 2017, 2016],
    '审计局人数（人）': [63, 63, 42, 40, 43],
    '完成审计项目（个）': [31, 26, 29, 31, 180],
    '审计查出主要问题金额（万元）': [358898, 449466, 410250, 322179, 26800],
    '审计期间整改金额（万元）': [21730, 19368, 66555, 14392, 2761],
    '审计处理处罚金额（万元）': [11696, 24339, 99594, 57038, 1163],
    '移送处理事项（件）': [24, 5, 6, 2, 6],
    '移送处理涉及金额（亿元）': [2.35, 1.27, 0.2123, 0.0176, 0.0306],
    '审计促进更改落实有关问题资金（万元）': [62177, 44412, 199780, 114813.11, 66278.34],
    '审计提出建议（条）': [442, 300, 359, 111, 264],
    '审计采纳建议（条）': [310, 281, 327, 99, 148],
    '提交审计信息（篇次）': [257, 46, 102, 43, 130],
    '被批示、采用审计信息（篇次）': [94, 49, 39, 21, 101],
    '提交审计报告数量（篇）': [41, 32, 36, 41, 271],
    '审计机关决算支出（万元）': [2020.84, 1805.96, 1511.81, 1256.89, 1104.45],
    '一般公共预算收入（亿元）': [124.5, 114.2, 106, 94.9, 91.7],
    '一般公共预算支出（亿元）': [430.6, 351.6, 315.7, 271.2, 248.2],
    '审计支出比率': [0.0469, 0.0514, 0.0479, 0.0463, 0.0445],
    '年末人口数（万人）': [411.7, 409.2, 406.6, 403.9, 401.8],
    '人均审计支出': [4.908525625, 4.413391984, 3.718175111, 3.11188413, 2.7487556],
    '审计效率指标_人均完成审计项目数': [0.492063492, 0.412698413, 0.69047619, 0.775, 4.186046512],
    '审计质量指标_整改率': [0.060546451, 0.043091135, 0.162230347, 0.04467082, 0.103022388],
    '审计质量指标_处罚率': [0.032588646, 0.054150926, 0.242764168, 0.17703823, 0.043395522],
    '审计效果指标_建议采纳率': [0.701357466, 0.936666667, 0.91086351, 0.891891892, 0.560606061],
    '审计效果指标_信息采用率': [0.365758755, 1.065217391, 0.382352941, 0.488372093, 0.776923077],
    '审计重视程度_人均审计支出': [4.908525625, 4.413391984, 3.718175111, 3.11188413, 2.7487556]
}

df_zhaoqing = pd.DataFrame(data)
df_zhaoqing
# Out:
#    地区    年份  审计局人数（人）  完成审计项目（个）  审计查出主要问题金额（万元）  审计期间整改金额（万元）  审计处理处罚金额（万元）  \
# 0  肇庆  2020        63         31          358898         21730         11696
# 1  肇庆  2019        63         26          449466         19368         24339
# 2  肇庆  2018        42         29          410250         66555         99594
# 3  肇庆  2017        40         31          322179         14392         57038
# 4  肇庆  2016        43        180           26800          2761          1163
#
#    移送处理事项（件）  移送处理涉及金额（亿元）  审计促进更改落实有关问题资金（万元）  ...  一般公共预算支出（亿元）  审计支出比率  \
# 0         24        2.3500            62177.00  ...         430.6  0.0469
# 1          5        1.2700            44412.00  ...         351.6  0.0514
# 2          6        0.2123           199780.00  ...         315.7  0.0479
# 3          2        0.0176           114813.11  ...         271.2  0.0463
# 4          6        0.0306            66278.34  ...         248.2  0.0445
#
# ...

# %%
data = {
    '地区': ['惠州', '惠州', '惠州', '惠州', '惠州'],
    '年份': [2020, 2019, 2018, 2017, 2016],
    '审计局人数（人）': [49, 49, 47, 49, 48],
    '完成审计项目（个）': [43, 50, 72, 77, 381],
    '审计查出主要问题金额（万元）': [632919, 748502, 460997, 404362, 31800],
    '审计期间整改金额（万元）': [8349, 78189, 29290, 12739, 7328],
    '审计处理处罚金额（万元）': [24459, 7979, 59409, 25637, 4313],
    '移送处理事项（件）': [29, 14, 26, 23, 42],
    '移送处理涉及金额（亿元）': [5.1, 2.35, 3.29, 1.09, 0.3856],
    '审计促进更改落实有关问题资金（万元）': [12150, 130953, 105121, 18218, 10793],
    '审计提出建议（条）': [151, 142, 194, 212, 563],
    '审计采纳建议（条）': [106, 113, 164, 186, 449],
    '提交审计信息（篇次）': [83, 32, 63, 119, 158],
    '被批示、采用审计信息（篇次）': [32, 11, 27, 53, 89],
    '提交审计报告数量（篇）': [62, 63, 99, 115, 511],
    '审计机关决算支出（万元）': [2566.15, 2693.65, 2276.27, 2104.53, 1745.07],
    '一般公共预算收入（亿元）': [412.2, 400.9, 393, 389.1, 361.3],
    '一般公共预算支出（亿元）': [637.2, 614.9, 544.2, 554, 509.1],
    '审计支出比率': [0.0403, 0.0438, 0.0418, 0.038, 0.0343],
    '年末人口数（万人）': [605.7, 597.2, 584.7, 572.2, 562.7],
    '人均审计支出': [4.236668318, 4.510465506, 3.893056268, 3.677962251, 3.101244002],
    '审计效率指标_人均完成审计项目数': [0.87755102, 1.020408163, 1.531914894, 1.571428571, 7.9375],
    '审计质量指标_整改率': [0.013191261, 0.104460643, 0.063536205, 0.031503949, 0.230440252],
    '审计质量指标_处罚率': [0.038644755, 0.010659958, 0.128870687, 0.063401111, 0.135628931],
    '审计效果指标_建议采纳率': [0.701986755, 0.795774648, 0.845360825, 0.877358491, 0.797513321],
    '审计效果指标_信息采用率': [0.385542169, 0.34375, 0.428571429, 0.445378151, 0.563291139],
    '审计重视程度_人均审计支出': [4.236668318, 4.510465506, 3.893056268, 3.677962251, 3.101244002]
}

df_huizhou = pd.DataFrame(data)

# 打印数据框
df_huizhou
# Out:
#    地区    年份  审计局人数（人）  完成审计项目（个）  审计查出主要问题金额（万元）  审计期间整改金额（万元）  审计处理处罚金额（万元）  \
# 0  惠州  2020        49         43          632919          8349         24459
# 1  惠州  2019        49         50          748502         78189          7979
# 2  惠州  2018        47         72          460997         29290         59409
# 3  惠州  2017        49         77          404362         12739         25637
# 4  惠州  2016        48        381           31800          7328          4313
#
#    移送处理事项（件）  移送处理涉及金额（亿元）  审计促进更改落实有关问题资金（万元）  ...  一般公共预算支出（亿元）  审计支出比率  \
# 0         29        5.1000               12150  ...         637.2  0.0403
# 1         14        2.3500              130953  ...         614.9  0.0438
# 2         26        3.2900              105121  ...         544.2  0.0418
# 3         23        1.0900               18218  ...         554.0  0.0380
# 4         42        0.3856               10793  ...         509.1  0.0343
#
# ...

# %%
import pandas as pd

data = {
    '地区': ['东莞', '东莞', '东莞', '东莞', '东莞'],
    '年份': [2020, 2019, 2018, 2017, 2016],
    '审计局人数（人）': [71, 74, 57, 52, 42],
    '完成审计项目（个）': [43, 31, 39, 53, 284],
    '审计查出主要问题金额（万元）': [628466, 383980, 470810, 748248, 704],
    '审计期间整改金额（万元）': [15201, 42688, 14778, 63217, 1921],
    '审计处理处罚金额（万元）': [274425, 300090, 213544, 520015, 2832],
    '移送处理事项（件）': [17, 23, 13, 21, 8],
    '移送处理涉及金额（亿元）': [1.93, 15.48, 2.09, 1.21, 0.5026],
    '审计促进更改落实有关问题资金（万元）': [207349, 299894, 213626, 262900, 10092],
    '审计提出建议（条）': [141, 164, 151, 197, 117],
    '审计采纳建议（条）': [138, 164, 143, 184, 102],
    '提交审计信息（篇次）': [54, 42, 55, 44, 40],
    '被批示、采用审计信息（篇次）': [25, 19, 17, 18, 31],
    '提交审计报告数量（篇）': [78, 61, 69, 70, 55],
    '审计机关决算支出（万元）': [4083.83, 3362.41, 2849.53, 2482.79, 2480.04],
    '一般公共预算收入（亿元）': [694.8, 673.3, 649.9, 592.1, 544.8],
    '一般公共预算支出（亿元）': [840.3, 863, 765.4, 667.6, 599.3],
    '审计支出比率': [0.0486, 0.0390, 0.0372, 0.0372, 0.0414],
    '年末人口数（万人）': [1048.4, 1045.5, 1043.8, 1038.2, 1016.6],
    '人均审计支出': [3.895297596, 3.216078431, 2.729957846, 2.391437103, 2.439543577],
    '审计效率指标_人均完成审计项目数': [0.478873239, 0.724137931, 0.530864198, 1, 0.98],
    '审计质量指标_整改率': [0.02083005, 0.057254831, 0.015709728, 0.037813191, 0.17],
    '审计质量指标_处罚率': [0.376046744, 0.402492559, 0.227007593, 0.311046498, 0.250619469],
    '审计效果指标_建议采纳率': [0.978723404, 1, 0.947019868, 0.934010152, 0.871794872],
    '审计效果指标_信息采用率': [0.462962963, 0.452380952, 0.309090909, 0.409090909, 0.775],
    '审计重视程度_人均审计支出': [3.895297596, 3.216078431, 2.729957846, 2.391437103, 2.439543577]
}

df_dongguan = pd.DataFrame(data)
df_dongguan
# Out:
#    地区    年份  审计局人数（人）  完成审计项目（个）  审计查出主要问题金额（万元）  审计期间整改金额（万元）  审计处理处罚金额（万元）  \
# 0  东莞  2020        71         43          628466         15201        274425
# 1  东莞  2019        74         31          383980         42688        300090
# 2  东莞  2018        57         39          470810         14778        213544
# 3  东莞  2017        52         53          748248         63217        520015
# 4  东莞  2016        42        284             704          1921          2832
#
#    移送处理事项（件）  移送处理涉及金额（亿元）  审计促进更改落实有关问题资金（万元）  ...  一般公共预算支出（亿元）  审计支出比率  \
# 0         17        1.9300              207349  ...         840.3  0.0486
# 1         23       15.4800              299894  ...         863.0  0.0390
# 2         13        2.0900              213626  ...         765.4  0.0372
# 3         21        1.2100              262900  ...         667.6  0.0372
# 4          8        0.5026               10092  ...         599.3  0.0414
#
# ...

# %%
data = {
    '地区': ['中山', '中山', '中山', '中山', '中山'],
    '年份': [2020, 2019, 2018, 2017, 2016],
    '审计局人数（人）': [84, 59, 75, 70, 60],
    '完成审计项目（个）': [19, 28, 33, 48, 49],
    '审计查出主要问题金额（万元）': [1585414, 3595858, 1341297, 1178926, 101800],
    '审计期间整改金额（万元）': [46887, 365219, 210712, 136826.43, 13728.08],
    '审计处理处罚金额（万元）': [327845, 121670, 120714, 293753, 26482],
    '移送处理事项（件）': [62, 35, 11, 18, 7],
    '移送处理涉及金额（亿元）': [7.21, 4.02, 1.96, 5.62, 3.93],
    '审计促进更改落实有关问题资金（万元）': [632174, 63994, 477071, 332205.89, 11669.77],
    '审计提出建议（条）': [51, 140, 97, 147, 77],
    '审计采纳建议（条）': [19, 90, 67, 71, 52],
    '提交审计信息（篇次）': [91, 53, 98, 71, 140],
    '被批示、采用审计信息（篇次）': [23, 29, 21, 24, 31],
    '提交审计报告数量（篇）': [28, 46, 42, 73, 83],
    '审计机关决算支出（万元）': [4876.98, 4257.63, 3302.1, 3028.7, 2803.23],
    '一般公共预算收入（亿元）': [287.6, 283.4, 315.2, 312.8, 295],
    '一般公共预算支出（亿元）': [375.6, 411.7, 437.9, 455.3, 366.9],
    '审计支出比率': [0.1298, 0.1034, 0.0754, 0.0665, 0.0764],
    '年末人口数（万人）': [443.1, 438.7, 428.8, 418, 407.7],
    '人均审计支出': [11.00649966, 9.705105995, 7.70079291, 7.24569378, 6.875717439],
    '审计效率指标_人均完成审计项目数': [0.226190476, 0.474576271, 0.44, 0.685714286, 0.816666667],
    '审计质量指标_整改率': [0.029573979, 0.10156658, 0.157095707, 0.116060236, 0.134853438],
    '审计质量指标_处罚率': [0.206788258, 0.033836153, 0.089997965, 0.249170007, 0.260137525],
    '审计效果指标_建议采纳率': [0.37254902, 0.642857143, 0.690721649, 0.482993197, 0.675324675],
    '审计效果指标_信息采用率': [0.252747253, 0.547169811, 0.214285714, 0.338028169, 0.221428571],
    '审计重视程度_人均审计支出': [11.00649966, 9.705105995, 7.70079291, 7.24569378, 6.875717439]
}

df_zhongshan = pd.DataFrame(data)
df_zhongshan
# Out:
#    地区    年份  审计局人数（人）  完成审计项目（个）  审计查出主要问题金额（万元）  审计期间整改金额（万元）  审计处理处罚金额（万元）  \
# 0  中山  2020        84         19         1585414      46887.00        327845
# 1  中山  2019        59         28         3595858     365219.00        121670
# 2  中山  2018        75         33         1341297     210712.00        120714
# 3  中山  2017        70         48         1178926     136826.43        293753
# 4  中山  2016        60         49          101800      13728.08         26482
#
#    移送处理事项（件）  移送处理涉及金额（亿元）  审计促进更改落实有关问题资金（万元）  ...  一般公共预算支出（亿元）  审计支出比率  \
# 0         62          7.21           632174.00  ...         375.6  0.1298
# 1         35          4.02            63994.00  ...         411.7  0.1034
# 2         11          1.96           477071.00  ...         437.9  0.0754
# 3         18          5.62           332205.89  ...         455.3  0.0665
# 4          7          3.93            11669.77  ...         366.9  0.0764
#
# ...

# %%
df = pd.concat(
    [df_guangzhou, df_zhaoqing, df_zhuhai, df_zhongshan, df_dongguan, df_foshan, df_jiangmen, df_shenzhen, df_huizhou])
df.reset_index()

df
# Out:
#    地区    年份  审计局人数（人）  完成审计项目（个）  审计查出主要问题金额（万元）  审计期间整改金额（万元）  审计处理处罚金额（万元）  \
# 0  广州  2020       178         94         2358883     270639.00        158104
# 1  广州  2019       192         48          942303     145807.00        268809
# 2  广州  2018       155         86         1757520     351012.00         41607
# 3  广州  2017       143        144         7512705      99500.00        536392
# 4  广州  2016       175        312         8297174      71365.00        253166
# 0  肇庆  2020        63         31          358898      21730.00         11696
# 1  肇庆  2019        63         26          449466      19368.00         24339
# 2  肇庆  2018        42         29          410250      66555.00         99594
# 3  肇庆  2017        40         31          322179      14392.00         57038
# 4  肇庆  2016        43        180           26800       2761.00          1163
# 0  珠海  2020        71         42          666961      14598.00         49850
# ...

# %%
df.to_csv('data.csv',index=False)
